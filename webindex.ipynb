# %%
from pathlib import Path

import pinecone
import requests
from langchain.document_loaders import (PagedPDFSplitter, TextLoader,
                                        UnstructuredHTMLLoader,
                                        UnstructuredMarkdownLoader,
                                        UnstructuredPDFLoader)
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Pinecone

# from urllib.parse import urlparse

TRUERA_BASE_URL = 'https://truera.com'
TRUREA_DOC_URL = 'https://docs.truera.com/1.34/public'
# Out:
# /home/piotrm/anaconda3/envs/demo3/lib/python3.10/site-packages/pinecone/index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
from bs4 import BeautifulSoup

# Create a pinecone vector db from a few blogs and docs.
# TODO: langchain includes html loaders which may produce better chunks.

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
pdf_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)

scrape_path = Path("webscrape")

collected = dict()
documents = []


def url_to_path(url):
    url_esc = url.replace("https://", "").replace("http://",
                                                  "").replace("/", ":")

    ext = ".html"

    if url_esc.endswith(".png"):
        ext = ""
    elif url_esc.endswith(".pdf"):
        ext = ""
    elif url_esc.endswith(".jpg"):
        ext = ""
    elif url_esc.endswith(".md"):
        ext = ""

    return scrape_path / (url_esc + ext)


def scrape(url):
    if url in collected:
        return

    collected[url] = True

    print(url)

    scrape_file = url_to_path(url)

    if str(url).endswith(".pdf"):
        # skipping for now since issues with the content extractors noted below
        return

    if scrape_file.exists():
        print("cached", end=" ")
        content = bytes()
        with scrape_file.open("rb") as fh:
            for line in fh.readlines():
                content += line
    else:
        print("downloading", end=" ")
        response = requests.get(url)

        if response.encoding is None:
            content = response.content

            with scrape_file.open("wb") as fh:
                fh.write(content)

        else:
            content = response.text

            with scrape_file.open("w") as fh:
                fh.write(content)

    loader = UnstructuredHTMLLoader
    if url.endswith(".pdf"):
        return
        loader = PagedPDFSplitter # freezes for some pdfs
        # loader = UnstructuredPDFLoader # cannot get requirement installation figured out
    elif url.endswith(".png"):
        return
    elif url.endswith(".jpg"):
        return
    elif url.endswith(".md"):
        loader = UnstructuredMarkdownLoader
    elif (not url.endswith("truera.com")) and (
            not url.endswith("truera.net")) and "." in url[-5:]:
        raise RuntimeError(f"Unhandled source type {url}")

    docs = loader(str(scrape_file)).load()
    print(f"got {len(docs)} document(s)")
    for doc in docs:
        doc.metadata['source'] = url
        documents.append(doc)

    try:
        soup = BeautifulSoup(content, 'html.parser')

    except Exception as e:
        print(e)
        return

    for surl in soup.findAll("a"):
        # print(url)
        sub = surl.get('href')
        if sub is not None:
            sub = str(sub)
            # print("\t", sub)

            if sub.startswith("mailto") or sub.startswith("tel"):
                continue

            if not (sub.startswith("http") or sub.startswith("//")):
                sub = url + "/" + sub

            # print("sub=", sub)

            if not (sub.startswith("https://truera.com")
                    or sub.startswith("https://support.truera.com")
                    or sub.startswith("https://marketing.truera.com")
                    or sub.startswith("https://go.truera.com")
                    or sub.startswith("https://app.truera.net")
                    or sub.startswith("https://docs.truera.com")):
                continue

            if "?" in sub:
                continue

            if "#" in sub:
                sub = sub.split("#")[0]

            while "/" == sub[-1]:
                sub = sub[0:-1]

            if sub.endswith("/."):
                continue

            if sub.endswith("/.."):
                continue

            if ".." in sub:
                continue

            if sub.endswith("//"):
                continue

            scrape(sub)

# %%
scrape(TRUERA_BASE_URL)
# Out:
# https://truera.com
# downloading got 1
# https://truera.com/ml-testing-and-debugging-the-missing-piece-in-ai-development
# downloading got 1
# https://truera.com/diagnostics
# downloading got 1
# https://truera.com/monitoring
# downloading got 1
# https://truera.com/platform
# downloading got 1
# https://truera.com/industries
# downloading got 1
# https://truera.com/ai-quality-management-for-banking
# downloading got 1
# https://truera.com/ai-quality-for-government
# downloading got 1
# https://truera.com/ai-quality-management-for-human-resources
# downloading got 1
# https://truera.com/ai-quality-insurance
# downloading got 1
# https://truera.com/manufacturing
# downloading got 1
# https://truera.com/retail-and-brands
# downloading got 1
# https://truera.com/why-truera
# downloading got 1
# https://truera.com/resources
# downloading got 1
# https://truera.com/events
# downloading got 1
# https://marketing.truera.com/trustworthy-ai-podcast
# downloading got 1
# https://truera.com/trustworthy-ai-in-financial-crime-compliance
# downloading got 1
# https://truera.com/ai-quality-blog
# downloading got 1
# https://support.truera.com
# downloading got 1
# https://truera.com/ai-quality-research
# downloading got 1
# https://truera.com/ai-quality-research/explainable-ai-research
# downloading got 1
# https://truera.com/ai-quality-research/trustworthy-ml-research
# downloading got 1
# https://truera.com/ai-quality-research/trustworthy-ml-education
# downloading got 1
# https://truera.com/ai-quality-research/ai-quality-education
# downloading got 1
# https://truera.com/how-to-debug-ml-model-performance-a-framework
# downloading got 1
# https://truera.com/ai-quality-leader
# downloading got 1
# https://truera.com/healthy-startup-culture
# downloading got 1
# https://truera.com/truera-best-machine-learning-jobs
# downloading got 1
# https://truera.com/company/partners/truera-intel-ai-partnership
# downloading got 1
# https://app.truera.net/home
# downloading got 1
# https://go.truera.com/contact-us
# downloading got 1
# https://truera.com/privacy-policy
# downloading got 1
# https://truera.com/category/data-science
# downloading got 1
# https://truera.com/category/ai-infrastructure
# downloading got 1
# https://truera.com/category/ai-quality
# downloading got 1
# https://truera.com/category/ai-regulation
# downloading got 1
# https://truera.com/category/business/banking
# downloading got 1
# https://truera.com/category/business
# downloading got 1
# https://truera.com/category/company-news
# downloading got 1
# https://truera.com/category/business/insurance
# downloading got 1
# https://truera.com/category/ml-monitoring
# downloading got 1
# https://truera.com/category/ml-test-harness
# downloading got 1
# https://truera.com/category/mlops
# downloading got 1
# https://truera.com/category/partnerships
# downloading got 1
# https://truera.com/category/people
# downloading got 1
# https://truera.com/tag/2021-ai-awards
# downloading got 1
# https://truera.com/tag/aiq-explainability
# downloading got 1
# https://truera.com/tag/ai-explainability
# downloading got 1
# https://truera.com/tag/ai-fairness
# downloading got 1
# https://truera.com/tag/ai-for-insurance
# downloading got 1
# https://truera.com/tag/ai-quality
# downloading got 1
# https://truera.com/tag/ai-quality-for-insurers
# downloading got 1
# https://truera.com/tag/ai-quality-infrastructure
# downloading got 1
# https://truera.com/tag/ai-quality-management
# downloading got 1
# https://truera.com/tag/ai-quality-monitoring
# downloading got 1
# https://truera.com/tag/ai-quality-systems
# downloading got 1
# https://truera.com/tag/ai-trust-gap
# downloading got 1
# https://truera.com/tag/artificial-intelligence-excellence-awards
# downloading got 1
# https://truera.com/tag/bias
# downloading got 1
# https://truera.com/tag/business-intelligence-group
# downloading got 1
# https://truera.com/tag/data-science
# downloading got 1
# https://truera.com/tag/deploying-truera
# downloading got 1
# https://truera.com/tag/docker
# downloading got 1
# https://truera.com/tag/enterprise-class-ai
# downloading got 1
# https://truera.com/tag/evaluating-ml-explainability-solutions
# downloading got 1
# https://truera.com/tag/financial-services
# downloading got 1
# https://truera.com/tag/kubernetes
# downloading got 1
# https://truera.com/tag/machine-learning
# downloading got 1
# https://truera.com/tag/microservices
# downloading got 1
# https://truera.com/tag/ml-bias
# downloading got 1
# https://truera.com/tag/ml-debugging
# downloading got 1
# https://truera.com/tag/ml-explainability
# downloading got 1
# https://truera.com/tag/ml-fairness
# downloading got 1
# https://truera.com/tag/ml-lifecycle
# downloading got 1
# https://truera.com/tag/ml-monitoring
# downloading got 1
# https://truera.com/tag/mlops
# downloading got 1
# https://truera.com/tag/ml-performance-management
# downloading got 1
# https://truera.com/tag/ml-testing
# downloading got 1
# https://truera.com/tag/model-analytics-performance
# downloading got 1
# https://truera.com/tag/model-execution-service
# downloading got 1
# https://truera.com/tag/model-explanations-and-analytics
# downloading got 1
# https://truera.com/tag/model-intelligence
# downloading got 1
# https://truera.com/tag/model-lifecycle-explainability
# downloading got 1
# https://truera.com/tag/model-performance-management
# downloading got 1
# https://truera.com/tag/model-quality
# downloading got 1
# https://truera.com/tag/model-stability
# downloading got 1
# https://truera.com/tag/standard-chartered
# downloading got 1
# https://truera.com/tag/tensorflow
# downloading got 1
# https://truera.com/tag/truera-advisors
# downloading got 1
# https://truera.com/tag/xai-2
# downloading got 1
# https://truera.com/go-beyond-explainability-using-the-shap-interface
# downloading got 1
# https://app.truera.net
# downloading got 1
# https://truera.com/tag/explainability
# downloading got 1
# https://truera.com/tag/shap
# downloading got 1
# https://truera.com/whats-missing-to-evaluate-foundation-models-at-scale
# downloading got 1
# https://go.truera.com/llm-testing-and-monitoring-notify-me
# downloading got 1
# https://truera.com/tag/feedback-functions
# downloading got 1
# https://truera.com/tag/foundation-model-monitoring
# downloading got 1
# https://truera.com/tag/foundation-model-testing
# downloading got 1
# https://truera.com/tag/foundation-models
# downloading got 1
# https://truera.com/how-to-interpret-and-use-feature-importance-in-ml-models
# downloading got 1
# https://truera.com/influence-sensitivity-plots-explained
# downloading got 1
# https://truera.com/wp-content/uploads/2020/08/Quantitative-Input-Influence-2016.pdf
# https://truera.com/tag/influence-sensitivity-plots
# downloading got 1
# https://truera.com/tag/qii
# downloading got 1
# https://truera.com/how-do-you-debug-and-address-model-drift
# downloading got 1
# https://truera.com/practical-guide-for-debugging-overfitting-in-ml
# downloading got 1
# https://truera.com/tag/overfitting
# downloading got 1
# https://truera.com/tag/ai-drift
# downloading got 1
# https://truera.com/tag/debug-model-drift
# downloading got 1
# https://truera.com/tag/mitigate-model-drift
# downloading got 1
# https://truera.com/tag/ml-drift
# downloading got 1
# https://truera.com/resource/in-the-news/page/5
# downloading got 1
# https://truera.com/resources/truera-selected-as-finalist-for-fast-companys-2021-world-changing-ideas-awards
# downloading got 1
# https://truera.com/resources/truera-to-co-lead-key-working-group-addressing-responsible-ai-in-financial-services
# downloading got 1
# https://truera.com/resource/in-the-news/page/6
# downloading got 1
# https://truera.com/wp-content/uploads/2020/08/machine-learning-explainability-in-finance-an-application-to-default-risk-analysis.pdf
# https://truera.com/research/explainable-ai-research
# downloading got 1
# https://truera.com/ai-quality-blog/page/2
# downloading got 1
# https://truera.com/ai-quality-blog/page/3
# downloading got 1
# https://truera.com/ai-quality-blog/page/4
# downloading got 1
# https://truera.com/ai-quality-blog/page/5
# downloading got 1
# https://truera.com/ai-quality-blog/page/6
# downloading got 1
# https://truera.com/ai-quality-blog/page/7
# downloading got 1
# https://truera.com/tag/financial-crime
# downloading got 1
# https://truera.com/tag/trustworthy-ai-podcast
# downloading got 1
# https://truera.com/event/podcasts
# downloading got 1
# https://truera.com/event/webinars
# downloading got 1
# https://truera.com/event/live-events
# downloading got 1
# https://truera.com/events/plug-and-play-alberta-2022-featuring-ai-quality
# downloading got 1
# https://truera.com/event/live-events/page/2
# downloading got 1
# https://go.truera.com/webinar-ai-governance
# downloading got 1
# https://marketing.truera.com/webinar-eu-ai-law
# downloading got 1
# https://marketing.truera.com/webinar-truera-monitoring
# downloading got 1
# https://truera.com/events/page/2
# downloading got 1
# https://truera.com/events/page/3
# downloading got 1
# https://truera.com/events/page/4
# downloading got 1
# https://truera.com/resources/page/2
# downloading got 1
# https://truera.com/resources/page/3
# downloading got 1
# https://truera.com/resources/page/4
# downloading got 1
# https://truera.com/resources/page/5
# downloading got 1
# https://truera.com/resources/page/6
# downloading got 1
# https://truera.com/resources/page/7
# downloading got 1
# https://truera.com/resources/page/8
# downloading got 1
# https://truera.com/resources/page/9
# downloading got 1
# https://go.truera.com/5-things-you-need-to-start-minimizing-bias-in-ai-and-machine-learning
# downloading got 1
# https://truera.com/wp-content/uploads/2020/08/Truera-Case-Study-Standard-Chartered-1.pdf
# https://truera.com/banking
# downloading got 1
# https://truera.com/government
# downloading got 1
# https://truera.com/wp-content/uploads/2021/05/TruEra-Monitoring-Datasheet-19-May-2021-172808.pdf
# https://truera.com/tag/ai-testing
# downloading got 1
# https://truera.com/tag/qa-for-ai
# downloading got 1
# https://truera.com/tag/qa-for-ml
# downloading got 1
# https://truera.com/tag/truera-diagnostics
# downloading got 1

# %%
scrape(TRUREA_DOC_URL)

# %%
len(documents)

# %%
# split scraped documents into chunks

text_splitter = CharacterTextSplitter(chunk_size=512, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

# %%
# keep only big ones

print(len(docs))
bigdocs = [doc for doc in docs if len(doc.page_content) > 256]
print(len(bigdocs))

# %%
# create / upload an index of the docs to pinecone

index_name = "llmdemo"
embedding = OpenAIEmbeddings(model='text-embedding-ada-002')  # 1536 dims
pinecone.create_index(index_name, dimension=1536)
Pinecone.from_documents(bigdocs, embedding, index_name=index_name)
