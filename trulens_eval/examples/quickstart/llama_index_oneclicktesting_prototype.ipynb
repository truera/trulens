# %% [markdown]
# # Llama-Index Quickstart
#
# In this quickstart you will create a simple Llama Index App and learn how to log it and get feedback on an LLM response.
#
# For evaluation, we will leverage the "hallucination triad" of groundedness, context relevance and answer relevance.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/truera/trulens/blob/main/trulens_eval/examples/quickstart/llama_index_quickstart.ipynb)

# %% [markdown]
# ## Setup
#
# ### Install dependencies
# Let's install some of the dependencies for this notebook if we don't have them already

# %%
# pip install trulens_eval==0.18.3 llama_index>=0.8.69 html2text>=2020.1.16

# %% [markdown]
# ### Add API keys
# For this quickstart, you will need Open AI and Huggingface keys. The OpenAI key is used for embeddings and GPT, and the Huggingface key is used for evaluation.

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-..."

# %% [markdown]
# ### Import from LlamaIndex and TruLens

# %%
from trulens_eval import Tru

tru = Tru()
# Out:
# 🦑 Tru initialized with db url sqlite:///default.sqlite .
# 🛑 Secret keys may be written to the database. See the `database_redact_keys` option of `Tru` to prevent this.

# %% [markdown]
# ### Create Simple LLM Application
#
# This example uses LlamaIndex which internally uses an OpenAI LLM.

# %%
from llama_index import VectorStoreIndex
from llama_index.readers.web import SimpleWebPageReader

documents = SimpleWebPageReader(
    html_to_text=True
).load_data(["http://paulgraham.com/worked.html"])
index = VectorStoreIndex.from_documents(documents)

query_engine = index.as_query_engine()

# %% [markdown]
# ### Send your first request

# %%
response = query_engine.query("What did the author do growing up?")
print(response)
# Out:
# The author mentioned that before college, they worked on two main things outside of school: writing and programming. They wrote short stories and also tried writing programs on an IBM 1401 computer.

# %% [markdown]
# ## Setup One Click Testing

# %%
import numpy as np
import logging
logger = logging.getLogger(__name__)
from logging import StreamHandler

# Create a logger and set the logging level
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# Create a StreamHandler to output logs to the notebook
handler = StreamHandler()
handler.setLevel(logging.INFO)
logger.addHandler(handler)

from trulens_eval import Feedback, TruLlama
from trulens_eval.feedback import Groundedness

class TruLlama_OneClick_Testing:
    def __init__(self, query_engine, feedback_provider):
        self.query_engine = query_engine
        self.feedback_provider = feedback_provider
        
    def generate_hallucination_test_cases(self, number_test_cases: int) -> str:
        """
        Inputs:
            number_test_cases: int - number of test cases you wish you to generate
        """
        logger.info("Generating test cases...")
        test_case_system_prompt = """Return a list of {number_test_cases} questions. Half should be about the data available, and half should seem like they are from the data available but be unanswerable. Respond in the format of a python list, for example: ["question 1", "question 2", ...]"""
        test_cases = eval(self.query_engine.query(test_case_system_prompt).response)

        return test_cases
    
    def get_rag_triad(self):
        logger.info("Defining feedback functions...")
        grounded = Groundedness(groundedness_provider=self.feedback_provider)
        f_groundedness = Feedback(grounded.groundedness_measure_with_cot_reasons, name = "Groundedness").on(
            TruLlama.select_source_nodes().node.text.collect()
            ).on_output(
            ).aggregate(grounded.grounded_statements_aggregator)

        # Question/answer relevance between overall question and answer.
        f_qa_relevance = Feedback(self.feedback_provider.relevance, name = "Answer Relevance").on_input_output()

        # Context relevance between question and each context chunk.
        f_context_relevance = Feedback(self.feedback_provider.qs_relevance, name = "Context Relevance").on_input().on(
            TruLlama.select_source_nodes().node.text
            ).aggregate(np.mean)
        
        hallucination_feedbacks = [f_groundedness, f_qa_relevance, f_context_relevance]

        return hallucination_feedbacks
    
    def get_recorder(self, feedbacks):
        logger.info("Setting up tracking...")
        return TruLlama(self.query_engine, feedbacks=feedbacks)
    
    def evaluate_hallucination(self, number_test_cases: int):
        test_cases = self.generate_hallucination_test_cases(number_test_cases)
        feedbacks = self.get_rag_triad()
        recorder = self.get_recorder(feedbacks)
        logger.info("Evaluating the app...")
        with recorder as recording:
            for test_case in test_cases:
                self.query_engine.query(test_case)

        return tru.get_leaderboard(app_ids=[recorder.app_id])

# %% [markdown]
# ## Run One-click Testing

# %%
from trulens_eval.feedback.provider import OpenAI

openai_provider = OpenAI()

oneclick = TruLlama_OneClick_Testing(query_engine, openai_provider)

oneclick.evaluate_hallucination(number_test_cases=10)
# Out:
# Generating test cases...
# Defining feedback functions...
# Setting up tracking...
# Evaluating the app...
# ✅ In Groundedness, input source will be set to __record__.app.query.rets.source_nodes[:].node.text.collect() .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input question will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input statement will be set to __record__.app.query.rets.source_nodes[:].node.text .
#                                            Context Relevance  Groundedness  \
# app_id
# app_hash_9875900db40ac95721921ee3305fd897               0.16           1.0
#
#                                            Answer Relevance  latency  \
# app_id
# app_hash_9875900db40ac95721921ee3305fd897            0.8375      1.5
#
#                                            total_cost
# app_id
# app_hash_9875900db40ac95721921ee3305fd897    0.003017

# %% [markdown]
# ## Explore in a Dashboard

# %%
tru.run_dashboard() # open a local streamlit app to explore

# tru.stop_dashboard() # stop if needed
# Out:
# Starting dashboard ...
# Config file already exists. Skipping writing process.
# Credentials file already exists. Skipping writing process.
# Accordion(children=(VBox(children=(VBox(children=(Label(value='STDOUT'), Output())), VBox(children=(Label(valu…
# Dashboard started at http://192.168.1.157:8501 .
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %% [markdown]
# Alternatively, you can run `trulens-eval` from a command line in the same folder to start the dashboard.

# %% [markdown]
# Note: Feedback functions evaluated in the deferred manner can be seen in the "Progress" page of the TruLens dashboard.

# %% [markdown]
# ## Or view results directly in your notebook

# %%
tru.get_records_and_feedback(app_ids=[])[0] # pass an empty list of app_ids to get all
# Out:
#                                         app_id  \
# 0    app_hash_2497bd1d5aaac828f47588fd987dfbaf
# 1    app_hash_2497bd1d5aaac828f47588fd987dfbaf
# 2    app_hash_2497bd1d5aaac828f47588fd987dfbaf
# 3    app_hash_2497bd1d5aaac828f47588fd987dfbaf
# 4    app_hash_2497bd1d5aaac828f47588fd987dfbaf
# ..                                         ...
# 121  app_hash_9875900db40ac95721921ee3305fd897
# 122  app_hash_9875900db40ac95721921ee3305fd897
# 123  app_hash_9875900db40ac95721921ee3305fd897
# 124  app_hash_9875900db40ac95721921ee3305fd897
# 125  app_hash_9875900db40ac95721921ee3305fd897
#
#                                               app_json  \
# 0    {"app_id": "app_hash_2497bd1d5aaac828f47588fd9...
# 1    {"app_id": "app_hash_2497bd1d5aaac828f47588fd9...
# 2    {"app_id": "app_hash_2497bd1d5aaac828f47588fd9...
# 3    {"app_id": "app_hash_2497bd1d5aaac828f47588fd9...
# 4    {"app_id": "app_hash_2497bd1d5aaac828f47588fd9...
# ..                                                 ...
# 121  {"app_id": "app_hash_9875900db40ac95721921ee33...
# 122  {"app_id": "app_hash_9875900db40ac95721921ee33...
# 123  {"app_id": "app_hash_9875900db40ac95721921ee33...
# 124  {"app_id": "app_hash_9875900db40ac95721921ee33...
# 125  {"app_id": "app_hash_9875900db40ac95721921ee33...
#
#                                                   type  \
# 0    RetrieverQueryEngine(llama_index.query_engine....
# 1    RetrieverQueryEngine(llama_index.query_engine....
# 2    RetrieverQueryEngine(llama_index.query_engine....
# 3    RetrieverQueryEngine(llama_index.query_engine....
# 4    RetrieverQueryEngine(llama_index.query_engine....
# ..                                                 ...
# 121  RetrieverQueryEngine(llama_index.query_engine....
# 122  RetrieverQueryEngine(llama_index.query_engine....
# 123  RetrieverQueryEngine(llama_index.query_engine....
# 124  RetrieverQueryEngine(llama_index.query_engine....
# 125  RetrieverQueryEngine(llama_index.query_engine....
#
#                                         record_id  \
# 0    record_hash_e6c7db7d5baa81f78a6f4637c79f4ad9
# 1    record_hash_363f9c89d7cc01acb5683745d0ba2870
# 2    record_hash_c60bf76608c7d23a607fe419603675eb
# 3    record_hash_813142bf883d4c95ee4db2f192839308
# 4    record_hash_61e503a7b4815776b62434a8265edcea
# ..                                            ...
# 121  record_hash_611884a3139e557af112a56a80d31ec5
# 122  record_hash_258604f25c031bf4b8c04f41b921f081
# 123  record_hash_012adcc2719ca18d831aaa58bcd40e27
# 124  record_hash_775d8725d86eafc69a76f10453c44375
# 125  record_hash_2a81727012f929ffdef4da1500cba595
#
#                                                  input  \
# 0    "What were the different shapes and sizes of t...
# 1                    "What were the problems with HN?"
# 2         "What was the worst thing about leaving YC?"
# 3    "What is an example of a concept that aliens w...
# 4    "What were some of the startups in the first b...
# ..                                                 ...
# 121  "What were the three things the author origina...
# 122  "What was the original name and purpose of Hac...
# 123  "What was the biggest source of stress for the...
# 124   "What did the author gradually stop working on?"
# 125  "How was YC different from other kinds of work...
#
#                                                 output tags  \
# 0    "The air conditioners were all different shape...    -
# 1    "The problems with HN were a 60% chance of it ...    -
# 2    "The worst thing about leaving YC was the real...    -
# 3    "The Pythagorean theorem is an example of a co...    -
# 4    "Some of the startups in the first batch funde...    -
# ..                                                 ...  ...
# 121  "The author originally intended to write short...    -
# 122  "The original name of Hacker News was Startup ...    -
# 123  "The biggest source of stress for the author i...    -
# 124  "The author gradually stopped working on writi...    -
# 125  "YC was different from other kinds of work the...    -
#
#                                            record_json  \
# 0    {"record_id": "record_hash_e6c7db7d5baa81f78a6...
# 1    {"record_id": "record_hash_363f9c89d7cc01acb56...
# 2    {"record_id": "record_hash_c60bf76608c7d23a607...
# 3    {"record_id": "record_hash_813142bf883d4c95ee4...
# 4    {"record_id": "record_hash_61e503a7b4815776b62...
# ..                                                 ...
# 121  {"record_id": "record_hash_611884a3139e557af11...
# 122  {"record_id": "record_hash_258604f25c031bf4b8c...
# 123  {"record_id": "record_hash_012adcc2719ca18d831...
# 124  {"record_id": "record_hash_775d8725d86eafc69a7...
# 125  {"record_id": "record_hash_2a81727012f929ffdef...
#
#                                              cost_json  \
# 0    {"n_requests": 2, "n_successful_requests": 2, ...
# 1    {"n_requests": 2, "n_successful_requests": 2, ...
# 2    {"n_requests": 2, "n_successful_requests": 2, ...
# 3    {"n_requests": 2, "n_successful_requests": 2, ...
# 4    {"n_requests": 2, "n_successful_requests": 2, ...
# ..                                                 ...
# 121  {"n_requests": 2, "n_successful_requests": 2, ...
# 122  {"n_requests": 2, "n_successful_requests": 2, ...
# 123  {"n_requests": 2, "n_successful_requests": 2, ...
# 124  {"n_requests": 2, "n_successful_requests": 2, ...
# 125  {"n_requests": 2, "n_successful_requests": 2, ...
#
#                                              perf_json  ...  \
# 0    {"start_time": "2023-12-07T17:09:17.182651", "...  ...
# 1    {"start_time": "2023-12-07T17:09:19.565124", "...  ...
# 2    {"start_time": "2023-12-07T17:09:23.205103", "...  ...
# 3    {"start_time": "2023-12-07T17:09:25.271943", "...  ...
# 4    {"start_time": "2023-12-07T17:09:27.402813", "...  ...
# ..                                                 ...  ...
# 121  {"start_time": "2023-12-07T17:46:09.385418", "...  ...
# 122  {"start_time": "2023-12-07T17:46:11.656759", "...  ...
# 123  {"start_time": "2023-12-07T17:46:13.534052", "...  ...
# 124  {"start_time": "2023-12-07T17:46:15.205647", "...  ...
# 125  {"start_time": "2023-12-07T17:46:16.649838", "...  ...
#
#            groundedness_measure_with_cot_reasons_calls  Answer Relevance  \
# 0    [{'args': {'source': ["[16] She reports that t...               NaN
# 1    [{'args': {'source': ['When I was dealing with...               NaN
# 2    [{'args': {'source': ['When I was dealing with...               NaN
# 3    [{'args': {'source': ["[16] She reports that t...               NaN
# 4    [{'args': {'source': ['We invited about 20 of ...               NaN
# ..                                                 ...               ...
# 121                                                NaN               1.0
# 122                                                NaN               NaN
# 123                                                NaN               NaN
# 124                                                NaN               NaN
# 125                                                NaN               NaN
#
#      Context Relevance  Groundedness  \
# 0                  NaN           NaN
# 1                  NaN           NaN
# 2                  NaN           NaN
# 3                  NaN           NaN
# 4                  NaN           NaN
# ..                 ...           ...
# 121                NaN           NaN
# 122                NaN           NaN
# 123                NaN           NaN
# 124                NaN           NaN
# 125                NaN           NaN
#
#                                 Answer Relevance_calls  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 121  [{'args': {'prompt': 'What were the three thin...
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
#
#     Context Relevance_calls Groundedness_calls  latency  total_tokens  \
# 0                       NaN                NaN        2          1596
# 1                       NaN                NaN        3          1676
# 2                       NaN                NaN        1          2129
# 3                       NaN                NaN        1          1602
# 4                       NaN                NaN        1          2127
# ..                      ...                ...      ...           ...
# 121                     NaN                NaN        1          2130
# 122                     NaN                NaN        2          2141
# 123                     NaN                NaN        1          2121
# 124                     NaN                NaN        1          2108
# 125                     NaN                NaN        2          2134
#
#      total_cost
# 0      0.002380
# 1      0.002555
# 2      0.003195
# 3      0.002392
# 4      0.003187
# ..          ...
# 121    0.003189
# 122    0.003221
# 123    0.003174
# 124    0.003158
# 125    0.003193
#
# [126 rows x 26 columns]
