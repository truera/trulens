# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from llama_index.readers.github import GithubRepositoryReader, GithubClient

github_token = "github_pat_..."

client = github_client = GithubClient(github_token=github_token, verbose=False)

reader = GithubRepositoryReader(
    github_client=github_client,
    owner="streamlit",
    repo="docs",
    use_parser=False,
    verbose=True,
    filter_directories=(
        ["content"],
        GithubRepositoryReader.FilterType.INCLUDE,
    ),
    filter_file_extensions=(
        [".md"],
        GithubRepositoryReader.FilterType.INCLUDE,
    )
)

# %%
documents = reader.load_data(branch="main")
# Out:
# current path:
# tree data: GitTreeResponseModel(sha='7e321edfb0977623e91faca009c6289988e08b56', url='https://api.github.com/repos/streamlit/docs/git/trees/7e321edfb0977623e91faca009c6289988e08b56', tree=[GitTreeResponseModel.GitTreeObject(path='.devcontainer', mode='040000', type='tree', sha='315fff0634bd9d935113f8e509abf6115b8aaa44', url='https://api.github.com/repos/streamlit/docs/git/trees/315fff0634bd9d935113f8e509abf6115b8aaa44', size=None), GitTreeResponseModel.GitTreeObject(path='.github', mode='040000', type='tree', sha='17a7444b275235e6d12f6badbad3bf6ad2590c5b', url='https://api.github.com/repos/streamlit/docs/git/trees/17a7444b275235e6d12f6badbad3bf6ad2590c5b', size=None), GitTreeResponseModel.GitTreeObject(path='.gitignore', mode='100644', type='blob', sha='2d7f31fab6c96ac8bd941545ff731254c80feda6', url='https://api.github.com/repos/streamlit/docs/git/blobs/2d7f31fab6c96ac8bd941545ff731254c80feda6', size=1728), GitTreeResponseModel.GitTreeObject(path='.husky', mode='040000', type='tree', sha='680c86f5d7389502766e56c18a58e441c049ef1a', url='https://api.github.com/repos/streamlit/docs/git/trees/680c86f5d7389502766e56c18a58e441c049ef1a', size=None), GitTreeResponseModel.GitTreeObject(path='.nvmrc', mode='100644', type='blob', sha='af9754bc40e637410a01019dab44542be44df6bf', url='https://api.github.com/repos/streamlit/docs/git/blobs/af9754bc40e637410a01019dab44542be44df6bf', size=8), GitTreeResponseModel.GitTreeObject(path='.prettierignore', mode='100644', type='blob', sha='005290e6199125c23e57d13ef179d715f3fbef09', url='https://api.github.com/repos/streamlit/docs/git/blobs/005290e6199125c23e57d13ef179d715f3fbef09', size=362), GitTreeResponseModel.GitTreeObject(path='.prettierrc.json', mode='100644', type='blob', sha='0967ef424bce6791893e9a57bb952f80fd536e93', url='https://api.github.com/repos/streamlit/docs/git/blobs/0967ef424bce6791893e9a57bb952f80fd536e93', size=3), GitTreeResponseModel.GitTreeObject(path='.streamlit', mode='040000', type='tree', sha='69efbddc83c6316905aeb5e3e17df81d95066341', url='https://api.github.com/repos/streamlit/docs/git/trees/69efbddc83c6316905aeb5e3e17df81d95066341', size=None), GitTreeResponseModel.GitTreeObject(path='LICENSE', mode='100644', type='blob', sha='261eeb9e9f8b2b4b0d119366dda99c6fd7d35c64', url='https://api.github.com/repos/streamlit/docs/git/blobs/261eeb9e9f8b2b4b0d119366dda99c6fd7d35c64', size=11357), GitTreeResponseModel.GitTreeObject(path='NOTICES', mode='100644', type='blob', sha='802099cdfe512882cc5b17b4b2b90ad3c9d1fa03', url='https://api.github.com/repos/streamlit/docs/git/blobs/802099cdfe512882cc5b17b4b2b90ad3c9d1fa03', size=20830), GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='23e7727a391d231cb32137a5e1afc5dc636af54c', url='https://api.github.com/repos/streamlit/docs/git/blobs/23e7727a391d231cb32137a5e1afc5dc636af54c', size=15687), GitTreeResponseModel.GitTreeObject(path='SECURITY.md', mode='100644', type='blob', sha='3651769cbc2972ff1ba64b5ef15ac43adfdf938a', url='https://api.github.com/repos/streamlit/docs/git/blobs/3651769cbc2972ff1ba64b5ef15ac43adfdf938a', size=417), GitTreeResponseModel.GitTreeObject(path='algolia', mode='040000', type='tree', sha='693ee0012146a13cff730b0110c69fc7a96526e0', url='https://api.github.com/repos/streamlit/docs/git/trees/693ee0012146a13cff730b0110c69fc7a96526e0', size=None), GitTreeResponseModel.GitTreeObject(path='components', mode='040000', type='tree', sha='f6568b90391c6af30cee2267ae10f3e3754f168e', url='https://api.github.com/repos/streamlit/docs/git/trees/f6568b90391c6af30cee2267ae10f3e3754f168e', size=None), GitTreeResponseModel.GitTreeObject(path='content', mode='040000', type='tree', sha='08d19d4e5518742680f73d26d956fb436c166fe5', url='https://api.github.com/repos/streamlit/docs/git/trees/08d19d4e5518742680f73d26d956fb436c166fe5', size=None), GitTreeResponseModel.GitTreeObject(path='context', mode='040000', type='tree', sha='081e46db03dcd7ca19942e79af14b2368c2f2e46', url='https://api.github.com/repos/strea ...
# processing tree 7e321edfb0977623e91faca009c6289988e08b56
# Checking .devcontainer whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if .devcontainer is a subdirectory of any of the filter directories
# ignoring .devcontainer due to filter
# Checking .github whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if .github is a subdirectory of any of the filter directories
# ignoring .github due to filter
# Checking .gitignore whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if .gitignore is a subdirectory of any of the filter directories
# ignoring .gitignore due to filter
# Checking .husky whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if .husky is a subdirectory of any of the filter directories
# ignoring .husky due to filter
# Checking .nvmrc whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if .nvmrc is a subdirectory of any of the filter directories
# ignoring .nvmrc due to filter
# Checking .prettierignore whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if .prettierignore is a subdirectory of any of the filter directories
# ignoring .prettierignore due to filter
# Checking .prettierrc.json whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if .prettierrc.json is a subdirectory of any of the filter directories
# ignoring .prettierrc.json due to filter
# Checking .streamlit whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if .streamlit is a subdirectory of any of the filter directories
# ignoring .streamlit due to filter
# Checking LICENSE whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if LICENSE is a subdirectory of any of the filter directories
# ignoring LICENSE due to filter
# Checking NOTICES whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if NOTICES is a subdirectory of any of the filter directories
# ignoring NOTICES due to filter
# Checking README.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if README.md is a subdirectory of any of the filter directories
# ignoring README.md due to filter
# Checking SECURITY.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if SECURITY.md is a subdirectory of any of the filter directories
# ignoring SECURITY.md due to filter
# Checking algolia whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if algolia is a subdirectory of any of the filter directories
# ignoring algolia due to filter
# Checking components whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if components is a subdirectory of any of the filter directories
# ignoring components due to filter
# Checking content whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content is a subdirectory of any of the filter directories
# tree object: GitTreeResponseModel.GitTreeObject(path='content', mode='040000', type='tree', sha='08d19d4e5518742680f73d26d956fb436c166fe5', url='https://api.github.com/repos/streamlit/docs/git/trees/08d19d4e5518742680f73d26d956fb436c166fe5', size=None)
# recursing into content
# 	current path: content
# 	tree data: GitTreeResponseModel(sha='08d19d4e5518742680f73d26d956fb436c166fe5', url='https://api.github.com/repos/streamlit/docs/git/trees/08d19d4e5518742680f73d26d956fb436c166fe5', tree=[GitTreeResponseModel.GitTreeObject(path='cookie-settings.md', mode='100644', type='blob', sha='b422adc73f96c45ce550f8486abc5032b37016fe', url='https://api.github.com/repos/streamlit/docs/git/blobs/b422adc73f96c45ce550f8486abc5032b37016fe', size=1088), GitTreeResponseModel.GitTreeObject(path='deploy', mode='040000', type='tree', sha='af6085745dc433cf3f26c543df00abb345cabf4d', url='https://api.github.com/repos/streamlit/docs/git/trees/af6085745dc433cf3f26c543df00abb345cabf4d', size=None), GitTreeResponseModel.GitTreeObject(path='develop', mode='040000', type='tree', sha='2696e2e0e035ddbdaaeeb32eaf19eb660125770e', url='https://api.github.com/repos/streamlit/docs/git/trees/2696e2e0e035ddbdaaeeb32eaf19eb660125770e', size=None), GitTreeResponseModel.GitTreeObject(path='gdpr-banner.md', mode='100644', type='blob', sha='af0887a472f2d7bb3360b2b33153fb874b00d022', url='https://api.github.com/repos/streamlit/docs/git/blobs/af0887a472f2d7bb3360b2b33153fb874b00d022', size=279), GitTreeResponseModel.GitTreeObject(path='get-started', mode='040000', type='tree', sha='97c4b246ad8c1d0e5bdac9dee7a0c2a8c02a3b2b', url='https://api.github.com/repos/streamlit/docs/git/trees/97c4b246ad8c1d0e5bdac9dee7a0c2a8c02a3b2b', size=None), GitTreeResponseModel.GitTreeObject(path='index.md', mode='100644', type='blob', sha='862893dfd3d97e00a4b54af0a397dd58ed062378', url='https://api.github.com/repos/streamlit/docs/git/blobs/862893dfd3d97e00a4b54af0a397dd58ed062378', size=3373), GitTreeResponseModel.GitTreeObject(path='kb', mode='040000', type='tree', sha='3a33995c5cc12318c1f123d358825b96365a8951', url='https://api.github.com/repos/streamlit/docs/git/trees/3a33995c5cc12318c1f123d358825b96365a8951', size=None), GitTreeResponseModel.GitTreeObject(path='menu.md', mode='100644', type='blob', sha='ca8118b5849b8a13f2b4578dafc035d55611156b', url='https://api.github.com/repos/streamlit/docs/git/blobs/ca8118b5849b8a13f2b4578dafc035d55611156b', size=47837)], truncated=False)
# 	processing tree 08d19d4e5518742680f73d26d956fb436c166fe5
# Checking content/cookie-settings.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/cookie-settings.md is a subdirectory of any of the filter directories
# Checking content/cookie-settings.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 	tree object: GitTreeResponseModel.GitTreeObject(path='cookie-settings.md', mode='100644', type='blob', sha='b422adc73f96c45ce550f8486abc5032b37016fe', url='https://api.github.com/repos/streamlit/docs/git/blobs/b422adc73f96c45ce550f8486abc5032b37016fe', size=1088)
# 	found blob cookie-settings.md
# 	blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='cookie-settings.md', mode='100644', type='blob', sha='b422adc73f96c45ce550f8486abc5032b37016fe', url='https://api.github.com/repos/streamlit/docs/git/blobs/b422adc73f96c45ce550f8486abc5032b37016fe', size=1088), 'content/cookie-settings.md')]
# Checking content/deploy whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy is a subdirectory of any of the filter directories
# 	tree object: GitTreeResponseModel.GitTreeObject(path='deploy', mode='040000', type='tree', sha='af6085745dc433cf3f26c543df00abb345cabf4d', url='https://api.github.com/repos/streamlit/docs/git/trees/af6085745dc433cf3f26c543df00abb345cabf4d', size=None)
# 	recursing into deploy
# 		current path: content/deploy
# 		tree data: GitTreeResponseModel(sha='af6085745dc433cf3f26c543df00abb345cabf4d', url='https://api.github.com/repos/streamlit/docs/git/trees/af6085745dc433cf3f26c543df00abb345cabf4d', tree=[GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='73226c95fb12b7aefc3365b0ac123ccaaa10f382', url='https://api.github.com/repos/streamlit/docs/git/blobs/73226c95fb12b7aefc3365b0ac123ccaaa10f382', size=1208), GitTreeResponseModel.GitTreeObject(path='community-cloud', mode='040000', type='tree', sha='983f7dcad634dcec40775cc236fb1a623ed36630', url='https://api.github.com/repos/streamlit/docs/git/trees/983f7dcad634dcec40775cc236fb1a623ed36630', size=None), GitTreeResponseModel.GitTreeObject(path='concepts', mode='040000', type='tree', sha='368ed11e48ca04f6e4cfa3a950c7c2f373763dc6', url='https://api.github.com/repos/streamlit/docs/git/trees/368ed11e48ca04f6e4cfa3a950c7c2f373763dc6', size=None), GitTreeResponseModel.GitTreeObject(path='tutorials', mode='040000', type='tree', sha='049362af3561ff681052f2eeb426caa37685fbc6', url='https://api.github.com/repos/streamlit/docs/git/trees/049362af3561ff681052f2eeb426caa37685fbc6', size=None)], truncated=False)
# 		processing tree af6085745dc433cf3f26c543df00abb345cabf4d
# Checking content/deploy/_index.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/_index.md is a subdirectory of any of the filter directories
# Checking content/deploy/_index.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 		tree object: GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='73226c95fb12b7aefc3365b0ac123ccaaa10f382', url='https://api.github.com/repos/streamlit/docs/git/blobs/73226c95fb12b7aefc3365b0ac123ccaaa10f382', size=1208)
# 		found blob _index.md
# 		blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='73226c95fb12b7aefc3365b0ac123ccaaa10f382', url='https://api.github.com/repos/streamlit/docs/git/blobs/73226c95fb12b7aefc3365b0ac123ccaaa10f382', size=1208), 'content/deploy/_index.md')]
# Checking content/deploy/community-cloud whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud is a subdirectory of any of the filter directories
# 		tree object: GitTreeResponseModel.GitTreeObject(path='community-cloud', mode='040000', type='tree', sha='983f7dcad634dcec40775cc236fb1a623ed36630', url='https://api.github.com/repos/streamlit/docs/git/trees/983f7dcad634dcec40775cc236fb1a623ed36630', size=None)
# 		recursing into community-cloud
# 			current path: content/deploy/community-cloud
# 			tree data: GitTreeResponseModel(sha='983f7dcad634dcec40775cc236fb1a623ed36630', url='https://api.github.com/repos/streamlit/docs/git/trees/983f7dcad634dcec40775cc236fb1a623ed36630', tree=[GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b7f4d34b629bdfe1c82d237a0c3647113cb94047', url='https://api.github.com/repos/streamlit/docs/git/blobs/b7f4d34b629bdfe1c82d237a0c3647113cb94047', size=2850), GitTreeResponseModel.GitTreeObject(path='deploy-your-app', mode='040000', type='tree', sha='96b0b085a323eafedf67b4b8d32e2bbe61dc0e41', url='https://api.github.com/repos/streamlit/docs/git/trees/96b0b085a323eafedf67b4b8d32e2bbe61dc0e41', size=None), GitTreeResponseModel.GitTreeObject(path='get-started', mode='040000', type='tree', sha='ceb9d51e1c3d18d1ad5cf431514edd42ee14b2f9', url='https://api.github.com/repos/streamlit/docs/git/trees/ceb9d51e1c3d18d1ad5cf431514edd42ee14b2f9', size=None), GitTreeResponseModel.GitTreeObject(path='manage-your-account', mode='040000', type='tree', sha='7eb88b3ef678effa622a34ba7ef6978197bf801d', url='https://api.github.com/repos/streamlit/docs/git/trees/7eb88b3ef678effa622a34ba7ef6978197bf801d', size=None), GitTreeResponseModel.GitTreeObject(path='manage-your-app', mode='040000', type='tree', sha='e7d2e7f8fd3f488f990fba35aae4a43f315d137b', url='https://api.github.com/repos/streamlit/docs/git/trees/e7d2e7f8fd3f488f990fba35aae4a43f315d137b', size=None), GitTreeResponseModel.GitTreeObject(path='share-your-app', mode='040000', type='tree', sha='1c8f3600b27fe05b0060f0c65ba26c361dfe9730', url='https://api.github.com/repos/streamlit/docs/git/trees/1c8f3600b27fe05b0060f0c65ba26c361dfe9730', size=None), GitTreeResponseModel.GitTreeObject(path='troubleshooting.md', mode='100644', type='blob', sha='e40125e5455e499987696831416c92882f44c8c1', url='https://api.github.com/repos/streamlit/docs/git/blobs/e40125e5455e499987696831416c92882f44c8c1', size=9785)], truncated=False)
# 			processing tree 983f7dcad634dcec40775cc236fb1a623ed36630
# Checking content/deploy/community-cloud/_index.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/_index.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/_index.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 			tree object: GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b7f4d34b629bdfe1c82d237a0c3647113cb94047', url='https://api.github.com/repos/streamlit/docs/git/blobs/b7f4d34b629bdfe1c82d237a0c3647113cb94047', size=2850)
# 			found blob _index.md
# 			blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b7f4d34b629bdfe1c82d237a0c3647113cb94047', url='https://api.github.com/repos/streamlit/docs/git/blobs/b7f4d34b629bdfe1c82d237a0c3647113cb94047', size=2850), 'content/deploy/community-cloud/_index.md')]
# Checking content/deploy/community-cloud/deploy-your-app whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/deploy-your-app is a subdirectory of any of the filter directories
# 			tree object: GitTreeResponseModel.GitTreeObject(path='deploy-your-app', mode='040000', type='tree', sha='96b0b085a323eafedf67b4b8d32e2bbe61dc0e41', url='https://api.github.com/repos/streamlit/docs/git/trees/96b0b085a323eafedf67b4b8d32e2bbe61dc0e41', size=None)
# 			recursing into deploy-your-app
# 				current path: content/deploy/community-cloud/deploy-your-app
# 				tree data: GitTreeResponseModel(sha='96b0b085a323eafedf67b4b8d32e2bbe61dc0e41', url='https://api.github.com/repos/streamlit/docs/git/trees/96b0b085a323eafedf67b4b8d32e2bbe61dc0e41', tree=[GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='1752c7a3cc7dc456c3f313852f558af434a70d0b', url='https://api.github.com/repos/streamlit/docs/git/blobs/1752c7a3cc7dc456c3f313852f558af434a70d0b', size=7365), GitTreeResponseModel.GitTreeObject(path='app-dependencies.md', mode='100644', type='blob', sha='b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', url='https://api.github.com/repos/streamlit/docs/git/blobs/b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', size=6370), GitTreeResponseModel.GitTreeObject(path='secrets-management.md', mode='100644', type='blob', sha='24fab2344a489c3fc2d6d4b3fa7adc15f4ab2b96', url='https://api.github.com/repos/streamlit/docs/git/blobs/24fab2344a489c3fc2d6d4b3fa7adc15f4ab2b96', size=5010)], truncated=False)
# 				processing tree 96b0b085a323eafedf67b4b8d32e2bbe61dc0e41
# Checking content/deploy/community-cloud/deploy-your-app/_index.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/deploy-your-app/_index.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/deploy-your-app/_index.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='1752c7a3cc7dc456c3f313852f558af434a70d0b', url='https://api.github.com/repos/streamlit/docs/git/blobs/1752c7a3cc7dc456c3f313852f558af434a70d0b', size=7365)
# 				found blob _index.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='1752c7a3cc7dc456c3f313852f558af434a70d0b', url='https://api.github.com/repos/streamlit/docs/git/blobs/1752c7a3cc7dc456c3f313852f558af434a70d0b', size=7365), 'content/deploy/community-cloud/deploy-your-app/_index.md')]
# Checking content/deploy/community-cloud/deploy-your-app/app-dependencies.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/deploy-your-app/app-dependencies.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/deploy-your-app/app-dependencies.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='app-dependencies.md', mode='100644', type='blob', sha='b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', url='https://api.github.com/repos/streamlit/docs/git/blobs/b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', size=6370)
# 				found blob app-dependencies.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='1752c7a3cc7dc456c3f313852f558af434a70d0b', url='https://api.github.com/repos/streamlit/docs/git/blobs/1752c7a3cc7dc456c3f313852f558af434a70d0b', size=7365), 'content/deploy/community-cloud/deploy-your-app/_index.md'), (GitTreeResponseModel.GitTreeObject(path='app-dependencies.md', mode='100644', type='blob', sha='b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', url='https://api.github.com/repos/streamlit/docs/git/blobs/b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', size=6370), 'content/deploy/community-cloud/deploy-your-app/app-dependencies.md')]
# Checking content/deploy/community-cloud/deploy-your-app/secrets-management.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/deploy-your-app/secrets-management.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/deploy-your-app/secrets-management.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='secrets-management.md', mode='100644', type='blob', sha='24fab2344a489c3fc2d6d4b3fa7adc15f4ab2b96', url='https://api.github.com/repos/streamlit/docs/git/blobs/24fab2344a489c3fc2d6d4b3fa7adc15f4ab2b96', size=5010)
# 				found blob secrets-management.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='1752c7a3cc7dc456c3f313852f558af434a70d0b', url='https://api.github.com/repos/streamlit/docs/git/blobs/1752c7a3cc7dc456c3f313852f558af434a70d0b', size=7365), 'content/deploy/community-cloud/deploy-your-app/_index.md'), (GitTreeResponseModel.GitTreeObject(path='app-dependencies.md', mode='100644', type='blob', sha='b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', url='https://api.github.com/repos/streamlit/docs/git/blobs/b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', size=6370), 'content/deploy/community-cloud/deploy-your-app/app-dependencies.md'), (GitTreeResponseModel.GitTreeObject(path='secrets-management.md', mode='100644', type='blob', sha='24fab2344a489c3fc2d6d4b3fa7adc15f4ab2b96', url='https://api.github.com/repos/streamlit/docs/git/blobs/24fab2344a489c3fc2d6d4b3fa7adc15f4ab2b96', size=5010), 'content/deploy/community-cloud/deploy-your-app/secrets-management.md')]
# 			blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b7f4d34b629bdfe1c82d237a0c3647113cb94047', url='https://api.github.com/repos/streamlit/docs/git/blobs/b7f4d34b629bdfe1c82d237a0c3647113cb94047', size=2850), 'content/deploy/community-cloud/_index.md'), (GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='1752c7a3cc7dc456c3f313852f558af434a70d0b', url='https://api.github.com/repos/streamlit/docs/git/blobs/1752c7a3cc7dc456c3f313852f558af434a70d0b', size=7365), 'content/deploy/community-cloud/deploy-your-app/_index.md'), (GitTreeResponseModel.GitTreeObject(path='app-dependencies.md', mode='100644', type='blob', sha='b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', url='https://api.github.com/repos/streamlit/docs/git/blobs/b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', size=6370), 'content/deploy/community-cloud/deploy-your-app/app-dependencies.md'), (GitTreeResponseModel.GitTreeObject(path='secrets-management.md', mode='100644', type='blob', sha='24fab2344a489c3fc2d6d4b3fa7adc15f4ab2b96', url='https://api.github.com/repos/streamlit/docs/git/blobs/24fab2344a489c3fc2d6d4b3fa7adc15f4ab2b96', size=5010), 'content/deploy/community-cloud/deploy-your-app/secrets-management.md')]
# Checking content/deploy/community-cloud/get-started whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/get-started is a subdirectory of any of the filter directories
# 			tree object: GitTreeResponseModel.GitTreeObject(path='get-started', mode='040000', type='tree', sha='ceb9d51e1c3d18d1ad5cf431514edd42ee14b2f9', url='https://api.github.com/repos/streamlit/docs/git/trees/ceb9d51e1c3d18d1ad5cf431514edd42ee14b2f9', size=None)
# 			recursing into get-started
# 				current path: content/deploy/community-cloud/get-started
# 				tree data: GitTreeResponseModel(sha='ceb9d51e1c3d18d1ad5cf431514edd42ee14b2f9', url='https://api.github.com/repos/streamlit/docs/git/trees/ceb9d51e1c3d18d1ad5cf431514edd42ee14b2f9', tree=[GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b4fb6c59556827ea49bdcf1642d3093653476ca7', url='https://api.github.com/repos/streamlit/docs/git/blobs/b4fb6c59556827ea49bdcf1642d3093653476ca7', size=1758), GitTreeResponseModel.GitTreeObject(path='connect-github.md', mode='100644', type='blob', sha='09b00a878de1855fc0b423fcd87c39989660a464', url='https://api.github.com/repos/streamlit/docs/git/blobs/09b00a878de1855fc0b423fcd87c39989660a464', size=4979), GitTreeResponseModel.GitTreeObject(path='create-your-account.md', mode='100644', type='blob', sha='db9c26f1cfafe43fb27864ff8560b1638e122349', url='https://api.github.com/repos/streamlit/docs/git/blobs/db9c26f1cfafe43fb27864ff8560b1638e122349', size=7322), GitTreeResponseModel.GitTreeObject(path='explore-your-workspace.md', mode='100644', type='blob', sha='d3683e3e14df7731f40f5f205d1c06bc0f62449e', url='https://api.github.com/repos/streamlit/docs/git/blobs/d3683e3e14df7731f40f5f205d1c06bc0f62449e', size=4033), GitTreeResponseModel.GitTreeObject(path='fork-and-edit.md', mode='100644', type='blob', sha='39525cc6636fc880cdbbea0086336cb97b363dc7', url='https://api.github.com/repos/streamlit/docs/git/blobs/39525cc6636fc880cdbbea0086336cb97b363dc7', size=2691), GitTreeResponseModel.GitTreeObject(path='quickstart.md', mode='100644', type='blob', sha='f5ae885699a87b44a2d19d8f8f06d4cd5fdc26b9', url='https://api.github.com/repos/streamlit/docs/git/blobs/f5ae885699a87b44a2d19d8f8f06d4cd5fdc26b9', size=7427), GitTreeResponseModel.GitTreeObject(path='security-model.md', mode='100644', type='blob', sha='de919778e73b8492e0d35b069839072e56a879cb', url='https://api.github.com/repos/streamlit/docs/git/blobs/de919778e73b8492e0d35b069839072e56a879cb', size=5406)], truncated=False)
# 				processing tree ceb9d51e1c3d18d1ad5cf431514edd42ee14b2f9
# Checking content/deploy/community-cloud/get-started/_index.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/get-started/_index.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/get-started/_index.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b4fb6c59556827ea49bdcf1642d3093653476ca7', url='https://api.github.com/repos/streamlit/docs/git/blobs/b4fb6c59556827ea49bdcf1642d3093653476ca7', size=1758)
# 				found blob _index.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b4fb6c59556827ea49bdcf1642d3093653476ca7', url='https://api.github.com/repos/streamlit/docs/git/blobs/b4fb6c59556827ea49bdcf1642d3093653476ca7', size=1758), 'content/deploy/community-cloud/get-started/_index.md')]
# Checking content/deploy/community-cloud/get-started/connect-github.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/get-started/connect-github.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/get-started/connect-github.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='connect-github.md', mode='100644', type='blob', sha='09b00a878de1855fc0b423fcd87c39989660a464', url='https://api.github.com/repos/streamlit/docs/git/blobs/09b00a878de1855fc0b423fcd87c39989660a464', size=4979)
# 				found blob connect-github.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b4fb6c59556827ea49bdcf1642d3093653476ca7', url='https://api.github.com/repos/streamlit/docs/git/blobs/b4fb6c59556827ea49bdcf1642d3093653476ca7', size=1758), 'content/deploy/community-cloud/get-started/_index.md'), (GitTreeResponseModel.GitTreeObject(path='connect-github.md', mode='100644', type='blob', sha='09b00a878de1855fc0b423fcd87c39989660a464', url='https://api.github.com/repos/streamlit/docs/git/blobs/09b00a878de1855fc0b423fcd87c39989660a464', size=4979), 'content/deploy/community-cloud/get-started/connect-github.md')]
# Checking content/deploy/community-cloud/get-started/create-your-account.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/get-started/create-your-account.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/get-started/create-your-account.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='create-your-account.md', mode='100644', type='blob', sha='db9c26f1cfafe43fb27864ff8560b1638e122349', url='https://api.github.com/repos/streamlit/docs/git/blobs/db9c26f1cfafe43fb27864ff8560b1638e122349', size=7322)
# 				found blob create-your-account.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b4fb6c59556827ea49bdcf1642d3093653476ca7', url='https://api.github.com/repos/streamlit/docs/git/blobs/b4fb6c59556827ea49bdcf1642d3093653476ca7', size=1758), 'content/deploy/community-cloud/get-started/_index.md'), (GitTreeResponseModel.GitTreeObject(path='connect-github.md', mode='100644', type='blob', sha='09b00a878de1855fc0b423fcd87c39989660a464', url='https://api.github.com/repos/streamlit/docs/git/blobs/09b00a878de1855fc0b423fcd87c39989660a464', size=4979), 'content/deploy/community-cloud/get-started/connect-github.md'), (GitTreeResponseModel.GitTreeObject(path='create-your-account.md', mode='100644', type='blob', sha='db9c26f1cfafe43fb27864ff8560b1638e122349', url='https://api.github.com/repos/streamlit/docs/git/blobs/db9c26f1cfafe43fb27864ff8560b1638e122349', size=7322), 'content/deploy/community-cloud/get-started/create-your-account.md')]
# Checking content/deploy/community-cloud/get-started/explore-your-workspace.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/get-started/explore-your-workspace.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/get-started/explore-your-workspace.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='explore-your-workspace.md', mode='100644', type='blob', sha='d3683e3e14df7731f40f5f205d1c06bc0f62449e', url='https://api.github.com/repos/streamlit/docs/git/blobs/d3683e3e14df7731f40f5f205d1c06bc0f62449e', size=4033)
# 				found blob explore-your-workspace.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b4fb6c59556827ea49bdcf1642d3093653476ca7', url='https://api.github.com/repos/streamlit/docs/git/blobs/b4fb6c59556827ea49bdcf1642d3093653476ca7', size=1758), 'content/deploy/community-cloud/get-started/_index.md'), (GitTreeResponseModel.GitTreeObject(path='connect-github.md', mode='100644', type='blob', sha='09b00a878de1855fc0b423fcd87c39989660a464', url='https://api.github.com/repos/streamlit/docs/git/blobs/09b00a878de1855fc0b423fcd87c39989660a464', size=4979), 'content/deploy/community-cloud/get-started/connect-github.md'), (GitTreeResponseModel.GitTreeObject(path='create-your-account.md', mode='100644', type='blob', sha='db9c26f1cfafe43fb27864ff8560b1638e122349', url='https://api.github.com/repos/streamlit/docs/git/blobs/db9c26f1cfafe43fb27864ff8560b1638e122349', size=7322), 'content/deploy/community-cloud/get-started/create-your-account.md'), (GitTreeResponseModel.GitTreeObject(path='explore-your-workspace.md', mode='100644', type='blob', sha='d3683e3e14df7731f40f5f205d1c06bc0f62449e', url='https://api.github.com/repos/streamlit/docs/git/blobs/d3683e3e14df7731f40f5f205d1c06bc0f62449e', size=4033), 'content/deploy/community-cloud/get-started/explore-your-workspace.md')]
# Checking content/deploy/community-cloud/get-started/fork-and-edit.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/get-started/fork-and-edit.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/get-started/fork-and-edit.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='fork-and-edit.md', mode='100644', type='blob', sha='39525cc6636fc880cdbbea0086336cb97b363dc7', url='https://api.github.com/repos/streamlit/docs/git/blobs/39525cc6636fc880cdbbea0086336cb97b363dc7', size=2691)
# 				found blob fork-and-edit.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b4fb6c59556827ea49bdcf1642d3093653476ca7', url='https://api.github.com/repos/streamlit/docs/git/blobs/b4fb6c59556827ea49bdcf1642d3093653476ca7', size=1758), 'content/deploy/community-cloud/get-started/_index.md'), (GitTreeResponseModel.GitTreeObject(path='connect-github.md', mode='100644', type='blob', sha='09b00a878de1855fc0b423fcd87c39989660a464', url='https://api.github.com/repos/streamlit/docs/git/blobs/09b00a878de1855fc0b423fcd87c39989660a464', size=4979), 'content/deploy/community-cloud/get-started/connect-github.md'), (GitTreeResponseModel.GitTreeObject(path='create-your-account.md', mode='100644', type='blob', sha='db9c26f1cfafe43fb27864ff8560b1638e122349', url='https://api.github.com/repos/streamlit/docs/git/blobs/db9c26f1cfafe43fb27864ff8560b1638e122349', size=7322), 'content/deploy/community-cloud/get-started/create-your-account.md'), (GitTreeResponseModel.GitTreeObject(path='explore-your-workspace.md', mode='100644', type='blob', sha='d3683e3e14df7731f40f5f205d1c06bc0f62449e', url='https://api.github.com/repos/streamlit/docs/git/blobs/d3683e3e14df7731f40f5f205d1c06bc0f62449e', size=4033), 'content/deploy/community-cloud/get-started/explore-your-workspace.md'), (GitTreeResponseModel.GitTreeObject(path='fork-and-edit.md', mode='100644', type='blob', sha='39525cc6636fc880cdbbea0086336cb97b363dc7', url='https://api.github.com/repos/streamlit/docs/git/blobs/39525cc6636fc880cdbbea0086336cb97b363dc7', size=2691), 'content/deploy/community-cloud/get-started/fork-and-edit.md')]
# Checking content/deploy/community-cloud/get-started/quickstart.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/get-started/quickstart.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/get-started/quickstart.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='quickstart.md', mode='100644', type='blob', sha='f5ae885699a87b44a2d19d8f8f06d4cd5fdc26b9', url='https://api.github.com/repos/streamlit/docs/git/blobs/f5ae885699a87b44a2d19d8f8f06d4cd5fdc26b9', size=7427)
# 				found blob quickstart.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b4fb6c59556827ea49bdcf1642d3093653476ca7', url='https://api.github.com/repos/streamlit/docs/git/blobs/b4fb6c59556827ea49bdcf1642d3093653476ca7', size=1758), 'content/deploy/community-cloud/get-started/_index.md'), (GitTreeResponseModel.GitTreeObject(path='connect-github.md', mode='100644', type='blob', sha='09b00a878de1855fc0b423fcd87c39989660a464', url='https://api.github.com/repos/streamlit/docs/git/blobs/09b00a878de1855fc0b423fcd87c39989660a464', size=4979), 'content/deploy/community-cloud/get-started/connect-github.md'), (GitTreeResponseModel.GitTreeObject(path='create-your-account.md', mode='100644', type='blob', sha='db9c26f1cfafe43fb27864ff8560b1638e122349', url='https://api.github.com/repos/streamlit/docs/git/blobs/db9c26f1cfafe43fb27864ff8560b1638e122349', size=7322), 'content/deploy/community-cloud/get-started/create-your-account.md'), (GitTreeResponseModel.GitTreeObject(path='explore-your-workspace.md', mode='100644', type='blob', sha='d3683e3e14df7731f40f5f205d1c06bc0f62449e', url='https://api.github.com/repos/streamlit/docs/git/blobs/d3683e3e14df7731f40f5f205d1c06bc0f62449e', size=4033), 'content/deploy/community-cloud/get-started/explore-your-workspace.md'), (GitTreeResponseModel.GitTreeObject(path='fork-and-edit.md', mode='100644', type='blob', sha='39525cc6636fc880cdbbea0086336cb97b363dc7', url='https://api.github.com/repos/streamlit/docs/git/blobs/39525cc6636fc880cdbbea0086336cb97b363dc7', size=2691), 'content/deploy/community-cloud/get-started/fork-and-edit.md'), (GitTreeResponseModel.GitTreeObject(path='quickstart.md', mode='100644', type='blob', sha='f5ae885699a87b44a2d19d8f8f06d4cd5fdc26b9', url='https://api.github.com/repos/streamlit/docs/git/blobs/f5ae885699a87b44a2d19d8f8f06d4cd5fdc26b9', size=7427), 'content/deploy/community-cloud/get-started/quickstart.md')]
# Checking content/deploy/community-cloud/get-started/security-model.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/get-started/security-model.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/get-started/security-model.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='security-model.md', mode='100644', type='blob', sha='de919778e73b8492e0d35b069839072e56a879cb', url='https://api.github.com/repos/streamlit/docs/git/blobs/de919778e73b8492e0d35b069839072e56a879cb', size=5406)
# 				found blob security-model.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b4fb6c59556827ea49bdcf1642d3093653476ca7', url='https://api.github.com/repos/streamlit/docs/git/blobs/b4fb6c59556827ea49bdcf1642d3093653476ca7', size=1758), 'content/deploy/community-cloud/get-started/_index.md'), (GitTreeResponseModel.GitTreeObject(path='connect-github.md', mode='100644', type='blob', sha='09b00a878de1855fc0b423fcd87c39989660a464', url='https://api.github.com/repos/streamlit/docs/git/blobs/09b00a878de1855fc0b423fcd87c39989660a464', size=4979), 'content/deploy/community-cloud/get-started/connect-github.md'), (GitTreeResponseModel.GitTreeObject(path='create-your-account.md', mode='100644', type='blob', sha='db9c26f1cfafe43fb27864ff8560b1638e122349', url='https://api.github.com/repos/streamlit/docs/git/blobs/db9c26f1cfafe43fb27864ff8560b1638e122349', size=7322), 'content/deploy/community-cloud/get-started/create-your-account.md'), (GitTreeResponseModel.GitTreeObject(path='explore-your-workspace.md', mode='100644', type='blob', sha='d3683e3e14df7731f40f5f205d1c06bc0f62449e', url='https://api.github.com/repos/streamlit/docs/git/blobs/d3683e3e14df7731f40f5f205d1c06bc0f62449e', size=4033), 'content/deploy/community-cloud/get-started/explore-your-workspace.md'), (GitTreeResponseModel.GitTreeObject(path='fork-and-edit.md', mode='100644', type='blob', sha='39525cc6636fc880cdbbea0086336cb97b363dc7', url='https://api.github.com/repos/streamlit/docs/git/blobs/39525cc6636fc880cdbbea0086336cb97b363dc7', size=2691), 'content/deploy/community-cloud/get-started/fork-and-edit.md'), (GitTreeResponseModel.GitTreeObject(path='quickstart.md', mode='100644', type='blob', sha='f5ae885699a87b44a2d19d8f8f06d4cd5fdc26b9', url='https://api.github.com/repos/streamlit/docs/git/blobs/f5ae885699a87b44a2d19d8f8f06d4cd5fdc26b9', size=7427), 'content/deploy/community-cloud/get-started/quickstart.md'), (GitTreeResponseModel.GitTreeObject(path='security-model.md', mode='100644', type='blob', sha='de919778e73b8492e0d35b069839072e56a879cb', url='https://api.github.com/repos/streamlit/docs/git/blobs/de919778e73b8492e0d35b069839072e56a879cb', size=5406), 'content/deploy/community-cloud/get-started/security-model.md')]
# 			blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b7f4d34b629bdfe1c82d237a0c3647113cb94047', url='https://api.github.com/repos/streamlit/docs/git/blobs/b7f4d34b629bdfe1c82d237a0c3647113cb94047', size=2850), 'content/deploy/community-cloud/_index.md'), (GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='1752c7a3cc7dc456c3f313852f558af434a70d0b', url='https://api.github.com/repos/streamlit/docs/git/blobs/1752c7a3cc7dc456c3f313852f558af434a70d0b', size=7365), 'content/deploy/community-cloud/deploy-your-app/_index.md'), (GitTreeResponseModel.GitTreeObject(path='app-dependencies.md', mode='100644', type='blob', sha='b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', url='https://api.github.com/repos/streamlit/docs/git/blobs/b9a865df8b49e7b70e88c466f13ef4cc2b5a0991', size=6370), 'content/deploy/community-cloud/deploy-your-app/app-dependencies.md'), (GitTreeResponseModel.GitTreeObject(path='secrets-management.md', mode='100644', type='blob', sha='24fab2344a489c3fc2d6d4b3fa7adc15f4ab2b96', url='https://api.github.com/repos/streamlit/docs/git/blobs/24fab2344a489c3fc2d6d4b3fa7adc15f4ab2b96', size=5010), 'content/deploy/community-cloud/deploy-your-app/secrets-management.md'), (GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='b4fb6c59556827ea49bdcf1642d3093653476ca7', url='https://api.github.com/repos/streamlit/docs/git/blobs/b4fb6c59556827ea49bdcf1642d3093653476ca7', size=1758), 'content/deploy/community-cloud/get-started/_index.md'), (GitTreeResponseModel.GitTreeObject(path='connect-github.md', mode='100644', type='blob', sha='09b00a878de1855fc0b423fcd87c39989660a464', url='https://api.github.com/repos/streamlit/docs/git/blobs/09b00a878de1855fc0b423fcd87c39989660a464', size=4979), 'content/deploy/community-cloud/get-started/connect-github.md'), (GitTreeResponseModel.GitTreeObject(path='create-your-account.md', mode='100644', type='blob', sha='db9c26f1cfafe43fb27864ff8560b1638e122349', url='https://api.github.com/repos/streamlit/docs/git/blobs/db9c26f1cfafe43fb27864ff8560b1638e122349', size=7322), 'content/deploy/community-cloud/get-started/create-your-account.md'), (GitTreeResponseModel.GitTreeObject(path='explore-your-workspace.md', mode='100644', type='blob', sha='d3683e3e14df7731f40f5f205d1c06bc0f62449e', url='https://api.github.com/repos/streamlit/docs/git/blobs/d3683e3e14df7731f40f5f205d1c06bc0f62449e', size=4033), 'content/deploy/community-cloud/get-started/explore-your-workspace.md'), (GitTreeResponseModel.GitTreeObject(path='fork-and-edit.md', mode='100644', type='blob', sha='39525cc6636fc880cdbbea0086336cb97b363dc7', url='https://api.github.com/repos/streamlit/docs/git/blobs/39525cc6636fc880cdbbea0086336cb97b363dc7', size=2691), 'content/deploy/community-cloud/get-started/fork-and-edit.md'), (GitTreeResponseModel.GitTreeObject(path='quickstart.md', mode='100644', type='blob', sha='f5ae885699a87b44a2d19d8f8f06d4cd5fdc26b9', url='https://api.github.com/repos/streamlit/docs/git/blobs/f5ae885699a87b44a2d19d8f8f06d4cd5fdc26b9', size=7427), 'content/deploy/community-cloud/get-started/quickstart.md'), (GitTreeResponseModel.GitTreeObject(path='security-model.md', mode='100644', type='blob', sha='de919778e73b8492e0d35b069839072e56a879cb', url='https://api.github.com/repos/streamlit/docs/git/blobs/de919778e73b8492e0d35b069839072e56a879cb', size=5406), 'content/deploy/community-cloud/get-started/security-model.md')]
# Checking content/deploy/community-cloud/manage-your-account whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/manage-your-account is a subdirectory of any of the filter directories
# 			tree object: GitTreeResponseModel.GitTreeObject(path='manage-your-account', mode='040000', type='tree', sha='7eb88b3ef678effa622a34ba7ef6978197bf801d', url='https://api.github.com/repos/streamlit/docs/git/trees/7eb88b3ef678effa622a34ba7ef6978197bf801d', size=None)
# 			recursing into manage-your-account
# 				current path: content/deploy/community-cloud/manage-your-account
# 				tree data: GitTreeResponseModel(sha='7eb88b3ef678effa622a34ba7ef6978197bf801d', url='https://api.github.com/repos/streamlit/docs/git/trees/7eb88b3ef678effa622a34ba7ef6978197bf801d', tree=[GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='65c36626cabca2058abe283424a9701b362fe9e0', url='https://api.github.com/repos/streamlit/docs/git/blobs/65c36626cabca2058abe283424a9701b362fe9e0', size=1493), GitTreeResponseModel.GitTreeObject(path='delete-your-account.md', mode='100644', type='blob', sha='1f9685b5b43955ebbe28b18d96069dd55de87f88', url='https://api.github.com/repos/streamlit/docs/git/blobs/1f9685b5b43955ebbe28b18d96069dd55de87f88', size=2043), GitTreeResponseModel.GitTreeObject(path='manage-your-github-connection.md', mode='100644', type='blob', sha='70de87f1281cbe26cd0e36ec66c69d21d40da65e', url='https://api.github.com/repos/streamlit/docs/git/blobs/70de87f1281cbe26cd0e36ec66c69d21d40da65e', size=5665), GitTreeResponseModel.GitTreeObject(path='sign-in-sign-out.md', mode='100644', type='blob', sha='3eeb9b8463eb632ab7a3ce3904d23f69cb3cd6b4', url='https://api.github.com/repos/streamlit/docs/git/blobs/3eeb9b8463eb632ab7a3ce3904d23f69cb3cd6b4', size=3278), GitTreeResponseModel.GitTreeObject(path='update-your-email.md', mode='100644', type='blob', sha='eae523bff8d468764baab27815006bf1d17fccf4', url='https://api.github.com/repos/streamlit/docs/git/blobs/eae523bff8d468764baab27815006bf1d17fccf4', size=5505), GitTreeResponseModel.GitTreeObject(path='workspace-settings.md', mode='100644', type='blob', sha='750b20be0cb08e33dc555317cd3ed4c8329e191d', url='https://api.github.com/repos/streamlit/docs/git/blobs/750b20be0cb08e33dc555317cd3ed4c8329e191d', size=1571)], truncated=False)
# 				processing tree 7eb88b3ef678effa622a34ba7ef6978197bf801d
# Checking content/deploy/community-cloud/manage-your-account/_index.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/manage-your-account/_index.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/manage-your-account/_index.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# 				tree object: GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='65c36626cabca2058abe283424a9701b362fe9e0', url='https://api.github.com/repos/streamlit/docs/git/blobs/65c36626cabca2058abe283424a9701b362fe9e0', size=1493)
# 				found blob _index.md
# 				blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='_index.md', mode='100644', type='blob', sha='65c36626cabca2058abe283424a9701b362fe9e0', url='https://api.github.com/repos/streamlit/docs/git/blobs/65c36626cabca2058abe283424a9701b362fe9e0', size=1493), 'content/deploy/community-cloud/manage-your-account/_index.md')]
# Checking content/deploy/community-cloud/manage-your-account/delete-your-account.md whether to FilterType.INCLUDE it based on the filter directories: ['content']
# Checking if content/deploy/community-cloud/manage-your-account/delete-your-account.md is a subdirectory of any of the filter directories
# Checking content/deploy/community-cloud/manage-your-account/delete-your-account.md whether to FilterType.INCLUDE it based on the filter file extensions: ['.md']
# ...
# generating document for content/develop/tutorials/databases/postgresql.md
# got 3860 characters- adding to documents - content/develop/tutorials/databases/postgresql.md
# Time to get blobs ([('private-gsheet.md', 6738), ('public-gsheet.md', 4222), ('snowflake.md', 6673), ('supabase.md', 8828), ('tableau.md', 5893)]): 0.25 seconds
# generating document for content/develop/tutorials/databases/private-gsheet.md
# got 6738 characters- adding to documents - content/develop/tutorials/databases/private-gsheet.md
# generating document for content/develop/tutorials/databases/public-gsheet.md
# got 4222 characters- adding to documents - content/develop/tutorials/databases/public-gsheet.md
# generating document for content/develop/tutorials/databases/snowflake.md
# got 6665 characters- adding to documents - content/develop/tutorials/databases/snowflake.md
# generating document for content/develop/tutorials/databases/supabase.md
# got 8824 characters- adding to documents - content/develop/tutorials/databases/supabase.md
# generating document for content/develop/tutorials/databases/tableau.md
# got 5875 characters- adding to documents - content/develop/tutorials/databases/tableau.md
# Time to get blobs ([('tidb.md', 5675), ('tigergraph.md', 3924), ('_index.md', 959), ('create-a-multiple-container-fragment.md', 9209), ('start-and-stop-fragment-auto-reruns.md', 11422)]): 0.24 seconds
# generating document for content/develop/tutorials/databases/tidb.md
# got 5675 characters- adding to documents - content/develop/tutorials/databases/tidb.md
# generating document for content/develop/tutorials/databases/tigergraph.md
# got 3918 characters- adding to documents - content/develop/tutorials/databases/tigergraph.md
# generating document for content/develop/tutorials/execution-flow/_index.md
# got 959 characters- adding to documents - content/develop/tutorials/execution-flow/_index.md
# generating document for content/develop/tutorials/execution-flow/fragments/create-a-multiple-container-fragment.md
# got 9118 characters- adding to documents - content/develop/tutorials/execution-flow/fragments/create-a-multiple-container-fragment.md
# generating document for content/develop/tutorials/execution-flow/fragments/start-and-stop-fragment-auto-reruns.md
# got 11422 characters- adding to documents - content/develop/tutorials/execution-flow/fragments/start-and-stop-fragment-auto-reruns.md
# Time to get blobs ([('trigger-a-full-script-rerun-from-a-fragment.md', 19312), ('_index.md', 492), ('conversational-apps.md', 20278), ('llm-quickstart.md', 5205), ('_index.md', 374)]): 0.22 seconds
# generating document for content/develop/tutorials/execution-flow/fragments/trigger-a-full-script-rerun-from-a-fragment.md
# got 19312 characters- adding to documents - content/develop/tutorials/execution-flow/fragments/trigger-a-full-script-rerun-from-a-fragment.md
# generating document for content/develop/tutorials/llms/_index.md
# got 492 characters- adding to documents - content/develop/tutorials/llms/_index.md
# generating document for content/develop/tutorials/llms/conversational-apps.md
# got 20272 characters- adding to documents - content/develop/tutorials/llms/conversational-apps.md
# generating document for content/develop/tutorials/llms/llm-quickstart.md
# got 5160 characters- adding to documents - content/develop/tutorials/llms/llm-quickstart.md
# generating document for content/develop/tutorials/multipage-apps/_index.md
# got 374 characters- adding to documents - content/develop/tutorials/multipage-apps/_index.md
# Time to get blobs ([('custom-navigation.md', 9297), ('gdpr-banner.md', 279), ('_index.md', 2288), ('_index.md', 1254), ('additional-features.md', 5907)]): 0.22 seconds
# generating document for content/develop/tutorials/multipage-apps/custom-navigation.md
# got 9238 characters- adding to documents - content/develop/tutorials/multipage-apps/custom-navigation.md
# generating document for content/gdpr-banner.md
# got 272 characters- adding to documents - content/gdpr-banner.md
# generating document for content/get-started/_index.md
# got 2282 characters- adding to documents - content/get-started/_index.md
# generating document for content/get-started/fundamentals/_index.md
# got 1254 characters- adding to documents - content/get-started/fundamentals/_index.md
# generating document for content/get-started/fundamentals/additional-features.md
# got 5857 characters- adding to documents - content/get-started/fundamentals/additional-features.md
# Time to get blobs ([('advanced-concepts.md', 9884), ('main-concepts.md', 14293), ('summary.md', 1046), ('_index.md', 958), ('create-a-multi-page-app.md', 19216)]): 0.23 seconds
# generating document for content/get-started/fundamentals/advanced-concepts.md
# got 9856 characters- adding to documents - content/get-started/fundamentals/advanced-concepts.md
# generating document for content/get-started/fundamentals/main-concepts.md
# got 14284 characters- adding to documents - content/get-started/fundamentals/main-concepts.md
# generating document for content/get-started/fundamentals/summary.md
# got 1046 characters- adding to documents - content/get-started/fundamentals/summary.md
# generating document for content/get-started/fundamentals/tutorials/_index.md
# got 958 characters- adding to documents - content/get-started/fundamentals/tutorials/_index.md
# generating document for content/get-started/fundamentals/tutorials/create-a-multi-page-app.md
# got 19137 characters- adding to documents - content/get-started/fundamentals/tutorials/create-a-multi-page-app.md
# Time to get blobs ([('create-an-app.md', 15138), ('_index.md', 1775), ('anaconda-distribution.md', 5860), ('cloud-quickstart.md', 7938), ('command-line.md', 4398)]): 0.22 seconds
# generating document for content/get-started/fundamentals/tutorials/create-an-app.md
# got 15113 characters- adding to documents - content/get-started/fundamentals/tutorials/create-an-app.md
# generating document for content/get-started/installation/_index.md
# got 1775 characters- adding to documents - content/get-started/installation/_index.md
# generating document for content/get-started/installation/anaconda-distribution.md
# got 5860 characters- adding to documents - content/get-started/installation/anaconda-distribution.md
# generating document for content/get-started/installation/cloud-quickstart.md
# got 7935 characters- adding to documents - content/get-started/installation/cloud-quickstart.md
# generating document for content/get-started/installation/command-line.md
# got 4396 characters- adding to documents - content/get-started/installation/command-line.md
# Time to get blobs ([('sis.md', 7465), ('index.md', 3373), ('_index.md', 2325), ('create-anchor-link.md', 957), ('enable-camera.md', 706)]): 0.21 seconds
# generating document for content/get-started/installation/sis.md
# got 7465 characters- adding to documents - content/get-started/installation/sis.md
# generating document for content/index.md
# got 3371 characters- adding to documents - content/index.md
# generating document for content/kb/FAQ/_index.md
# got 2324 characters- adding to documents - content/kb/FAQ/_index.md
# generating document for content/kb/FAQ/create-anchor-link.md
# got 957 characters- adding to documents - content/kb/FAQ/create-anchor-link.md
# generating document for content/kb/FAQ/enable-camera.md
# got 706 characters- adding to documents - content/kb/FAQ/enable-camera.md
# Time to get blobs ([('how-download-file-streamlit.md', 1767), ('how-download-pandas-dataframe-csv.md', 1242), ('how-to-get-row-selections.md', 2271), ('insert-elements-out-of-order.md', 779), ('pydeck-chart-custom-mapbox-styles.md', 710)]): 0.21 seconds
# generating document for content/kb/FAQ/how-download-file-streamlit.md
# got 1767 characters- adding to documents - content/kb/FAQ/how-download-file-streamlit.md
# generating document for content/kb/FAQ/how-download-pandas-dataframe-csv.md
# got 1242 characters- adding to documents - content/kb/FAQ/how-download-pandas-dataframe-csv.md
# generating document for content/kb/FAQ/how-to-get-row-selections.md
# got 2271 characters- adding to documents - content/kb/FAQ/how-to-get-row-selections.md
# generating document for content/kb/FAQ/insert-elements-out-of-order.md
# got 779 characters- adding to documents - content/kb/FAQ/insert-elements-out-of-order.md
# generating document for content/kb/FAQ/pydeck-chart-custom-mapbox-styles.md
# got 710 characters- adding to documents - content/kb/FAQ/pydeck-chart-custom-mapbox-styles.md
# Time to get blobs ([('remove-streamlit-app-title.md', 521), ('retrieve-filename-uploaded.md', 1085), ('sanity-checks.md', 9410), ('serializable-session-state.md', 2295), ('streamlit-watch-changes-other-modules-importing-app.md', 564)]): 0.24 seconds
# generating document for content/kb/FAQ/remove-streamlit-app-title.md
# got 515 characters- adding to documents - content/kb/FAQ/remove-streamlit-app-title.md
# generating document for content/kb/FAQ/retrieve-filename-uploaded.md
# got 1085 characters- adding to documents - content/kb/FAQ/retrieve-filename-uploaded.md
# generating document for content/kb/FAQ/sanity-checks.md
# got 9408 characters- adding to documents - content/kb/FAQ/sanity-checks.md
# generating document for content/kb/FAQ/serializable-session-state.md
# got 2284 characters- adding to documents - content/kb/FAQ/serializable-session-state.md
# generating document for content/kb/FAQ/streamlit-watch-changes-other-modules-importing-app.md
# got 564 characters- adding to documents - content/kb/FAQ/streamlit-watch-changes-other-modules-importing-app.md
# Time to get blobs ([('supported-browsers.md', 696), ('upgrade-version-streamlit.md', 1991), ('where-file-uploader-store-when-deleted.md', 1294), ('why-streamlit-restrict-nested-columns.md', 1327), ('widget-updating-session-state.md', 2317)]): 0.30 seconds
# generating document for content/kb/FAQ/supported-browsers.md
# got 696 characters- adding to documents - content/kb/FAQ/supported-browsers.md
# generating document for content/kb/FAQ/upgrade-version-streamlit.md
# got 1987 characters- adding to documents - content/kb/FAQ/upgrade-version-streamlit.md
# generating document for content/kb/FAQ/where-file-uploader-store-when-deleted.md
# got 1292 characters- adding to documents - content/kb/FAQ/where-file-uploader-store-when-deleted.md
# generating document for content/kb/FAQ/why-streamlit-restrict-nested-columns.md
# got 1327 characters- adding to documents - content/kb/FAQ/why-streamlit-restrict-nested-columns.md
# generating document for content/kb/FAQ/widget-updating-session-state.md
# got 2314 characters- adding to documents - content/kb/FAQ/widget-updating-session-state.md
# Time to get blobs ([('_index.md', 987), ('_index.md', 569), ('install-package-pypi-github.md', 2416), ('libgl.md', 1046), ('module-not-found-error.md', 1101)]): 0.23 seconds
# generating document for content/kb/_index.md
# got 987 characters- adding to documents - content/kb/_index.md
# generating document for content/kb/dependencies/_index.md
# got 569 characters- adding to documents - content/kb/dependencies/_index.md
# generating document for content/kb/dependencies/install-package-pypi-github.md
# got 2416 characters- adding to documents - content/kb/dependencies/install-package-pypi-github.md
# generating document for content/kb/dependencies/libgl.md
# got 1046 characters- adding to documents - content/kb/dependencies/libgl.md
# generating document for content/kb/dependencies/module-not-found-error.md
# got 1097 characters- adding to documents - content/kb/dependencies/module-not-found-error.md
# Time to get blobs ([('no-matching-distribution.md', 2090), ('_index.md', 2239), ('authentication-without-sso.md', 7172), ('deploy-multiple-streamlit-apps-different-subdomains.md', 1404), ('deploy-streamlit-domain-port-80.md', 1334)]): 0.27 seconds
# generating document for content/kb/dependencies/no-matching-distribution.md
# got 2090 characters- adding to documents - content/kb/dependencies/no-matching-distribution.md
# generating document for content/kb/deployments/_index.md
# got 2239 characters- adding to documents - content/kb/deployments/_index.md
# generating document for content/kb/deployments/authentication-without-sso.md
# got 7166 characters- adding to documents - content/kb/deployments/authentication-without-sso.md
# generating document for content/kb/deployments/deploy-multiple-streamlit-apps-different-subdomains.md
# got 1402 characters- adding to documents - content/kb/deployments/deploy-multiple-streamlit-apps-different-subdomains.md
# generating document for content/kb/deployments/deploy-streamlit-domain-port-80.md
# got 1333 characters- adding to documents - content/kb/deployments/deploy-streamlit-domain-port-80.md
# Time to get blobs ([('does-streamlit-support-wsgi-protocol.md', 726), ('how-to-submit-a-support-case-for-streamlit-community-cloud.md', 1758), ('huh-this-is-isnt-supposed-to-happen-message-after-trying-to-log-in.md', 1288), ('increase-upload-limit-cloud.md', 2067), ('invoking-python-subprocess-deployed-streamlit-app.md', 1903)]): 0.24 seconds
# generating document for content/kb/deployments/does-streamlit-support-wsgi-protocol.md
# got 726 characters- adding to documents - content/kb/deployments/does-streamlit-support-wsgi-protocol.md
# generating document for content/kb/deployments/how-to-submit-a-support-case-for-streamlit-community-cloud.md
# got 1758 characters- adding to documents - content/kb/deployments/how-to-submit-a-support-case-for-streamlit-community-cloud.md
# generating document for content/kb/deployments/huh-this-is-isnt-supposed-to-happen-message-after-trying-to-log-in.md
# got 1286 characters- adding to documents - content/kb/deployments/huh-this-is-isnt-supposed-to-happen-message-after-trying-to-log-in.md
# generating document for content/kb/deployments/increase-upload-limit-cloud.md
# got 2061 characters- adding to documents - content/kb/deployments/increase-upload-limit-cloud.md
# generating document for content/kb/deployments/invoking-python-subprocess-deployed-streamlit-app.md
# got 1899 characters- adding to documents - content/kb/deployments/invoking-python-subprocess-deployed-streamlit-app.md
# Time to get blobs ([('login-attempt-to-streamlit-community-cloud-fails-with-error-403.md', 619), ('organize-apps-workspaces.md', 1752), ('remote-start.md', 4610), ('resource-limits.md', 1869), ('unable-to-edit-or-delete-apps-in-streamlit-community-cloud-after-modifying-github-username.md', 749)]): 0.27 seconds
# generating document for content/kb/deployments/login-attempt-to-streamlit-community-cloud-fails-with-error-403.md
# got 619 characters- adding to documents - content/kb/deployments/login-attempt-to-streamlit-community-cloud-fails-with-error-403.md
# generating document for content/kb/deployments/organize-apps-workspaces.md
# got 1750 characters- adding to documents - content/kb/deployments/organize-apps-workspaces.md
# generating document for content/kb/deployments/remote-start.md
# got 4606 characters- adding to documents - content/kb/deployments/remote-start.md
# generating document for content/kb/deployments/resource-limits.md
# got 1869 characters- adding to documents - content/kb/deployments/resource-limits.md
# generating document for content/kb/deployments/unable-to-edit-or-delete-apps-in-streamlit-community-cloud-after-modifying-github-username.md
# got 749 characters- adding to documents - content/kb/deployments/unable-to-edit-or-delete-apps-in-streamlit-community-cloud-after-modifying-github-username.md
# Time to get blobs ([('upgrade-streamlit-version.md', 2234), ('view-only-access-to-app-after-changing-github-username-or-repository-name.md', 923), ('menu.md', 47837)]): 0.20 seconds
# generating document for content/kb/deployments/upgrade-streamlit-version.md
# got 2231 characters- adding to documents - content/kb/deployments/upgrade-streamlit-version.md
# generating document for content/kb/deployments/view-only-access-to-app-after-changing-github-username-or-repository-name.md
# got 923 characters- adding to documents - content/kb/deployments/view-only-access-to-app-after-changing-github-username-or-repository-name.md
# generating document for content/menu.md
# got 47834 characters- adding to documents - content/menu.md

# %%
import re

def clean_up_text(content: str) -> str:
    """
    Remove unwanted characters and patterns in text input.

    :param content: Text input.
    
    :return: Cleaned version of original text input.
    """

    # Fix hyphenated words broken by newline
    content = re.sub(r'(\w+)-\n(\w+)', r'\1\2', content)

    unwanted_patterns = ['---\nvisible: false','---', '#','slug:']
    for pattern in unwanted_patterns:
        content = re.sub(pattern, "", content)

    # Remove all slugs starting with a \ and stopping at the first space
    content = re.sub(r'\\slug: [^\s]*', '', content)

    # normalize whitespace
    content = re.sub(r'\s+', ' ', content)
    return content

# %%
cleaned_documents = []

for d in documents:
    cleaned_text = clean_up_text(d.text)
    d.text = cleaned_text
    cleaned_documents.append(d)

# %%
from pinecone import Pinecone, ServerlessSpec
pinecone_api_key = "..."
pc = Pinecone(api_key=pinecone_api_key)


index_name = "streamlit-docs"

if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=768,
        metric="cosine",
        spec=ServerlessSpec(
            cloud='aws', 
            region='us-east-1'
        ) 
    ) 

pinecone_index = pc.Index(index_name)

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

embed_model = HuggingFaceEmbedding("Snowflake/snowflake-arctic-embed-m")

from llama_index.core.node_parser import SemanticSplitterNodeParser

splitter = SemanticSplitterNodeParser(
    buffer_size=1, breakpoint_percentile_threshold=95, embed_model=embed_model
)

# %%
nodes = splitter.get_nodes_from_documents(cleaned_documents)

# %%
from llama_index.vector_stores.pinecone import PineconeVectorStore
from llama_index.core import StorageContext, VectorStoreIndex

vector_store = PineconeVectorStore(pinecone_index=pinecone_index)

# setup our storage (vector db)
storage_context = StorageContext.from_defaults(
    vector_store=vector_store
)

index = VectorStoreIndex.from_documents(cleaned_documents, storage_context=storage_context, embed_model=embed_model)
# Out:
# Upserted vectors: 100%|██████████| 566/566 [00:04<00:00, 126.38it/s]
